# %% [markdown]
# <a href="https://colab.research.google.com/github/himani098/python-fundamentals/blob/main/day24_2026_06_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# E-commerce (Electronic Commerce) means:
#
# Buying and selling goods or services over the internet.

# %% [markdown]
# A transaction is a group of one or more SQL operations that are treated as a single unit of work.
#
# COMMIT is an SQL command that permanently saves all changes made during the current transaction to the database.
#
# ROLLBACK is an SQL command that undoes all changes made during the current transaction that have not yet been committed.

# %% [markdown]
# https://www.mongodb.com/cloud/atlas/register --> for set up of mongodb

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# mean :- average :- sum of all the elements / total number of elements
#
# mode - most repeating element (if no repeatation then no mode)(can have more than one value also)
#
# median - middle number after doing ascending sorting(if even number of numbers are present then we find the average of middle 2 numbers)
#
# percentage = (sum of all the provided values / sum of total values) * 100
#
# ratio - comparing two quantities
#
# q1 : q2 --> q1 + q2 = 100
#
# vector - 1d
#
# matrix - 2d
#
# tensor - 3d
#
# standard deviation - to much difference btw values then high standard deviation present in it

# %% [markdown]
# ML -
#
# foundations of ML -
#
# 1) understanding ML purpose- prediction -weather,cricket,sales, email, stock
# 2) differentiate AI,ML,DL
# 3) explore ML types
# 4) ML concepts(scikit learn)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# types of ML -
# 1) supervised learning - we are giving both input & output & prediction on both is done then
# 2) unsupervised learning - only input given(various categories of input data & for new data we check for whose pattern matches with it then)
# 3) reinforcement learning -

# %% [markdown]
# ML concept-
#
# 1) input - X variable - data taken from user
#
# 2) output - y variable - data given by machine after performing operation
#
# 3) model- trained and then giving answers
#
# 4) training - giving training on some model or data to check for rest in testing --> X-train , y-train
#
# 5) testing - X-test, y-test
#
# 6) prediction - error in output or prediction
