# %% [markdown]
# <a href="https://colab.research.google.com/github/himani098/python-fundamentals/blob/main/day1_2026_05_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **module** - a .py file
#
# **package** - collection of modules, works like a folder
#
# **library** - collection of packages and modules
# ex - import math
#
# **framework** - already existing structure of an application
# ex - fast api, django , flask
#
# **full stack** = frontend + backend
#
# **frontend** - react
#
# **backend** - express , node , django, spring
#
# **python** - high level language(human understable)

# %%
a = 10
b = a
a = 30
print(a,b)
print(id(a),id(b))
#id() -> to access the memory address
# Out:
# 30 10
# 11646280 11645640

# %%
a = 10
b = 10
print(a,b)
print(id(a),id(b))
#same values gets stored at same address
# Out:
# 10 10
# 11645640 11645640

# %%
# integer
a = 10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
#float
b = 10.10
print(b)
print(type(b))
# Out:
# 10.1
# <class 'float'>

# %%
# string
c = "hello"
print(c)
print(type(c))
# Out:
# hello
# <class 'str'>

# %%
# boolean
d = False
print(d)
print(type(d))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# Python is an interpreted language. Internally, Python first compiles source code into bytecode and then executes it using the Python Virtual Machine (PVM).
# Both compiler & interpreter are present but it is largely an interpreted language.
