# %% [markdown]
# <a href="https://colab.research.google.com/github/himani098/python-fundamentals/blob/main/day15_2026_06_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      101     10
# 1     kunal      102     20
# 2  abhishek      103     30
# 3   praveen      104     40
# 4    anjali      105     50

# %% [markdown]
# Basic Dataframe Understanding:-
#
# 1) head()
# 2) tail()
# 3) shape
# 4) info()
# 5) rename
# 6) describe()-> count,mean,std,min,max

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
# print(df)

#head -> It is used to display the first few rows of a DataFrame or Series.
# df.head(n)
# n → Number of rows to display (optional).
# If n is not given, it displays the first 5 rows.

print(df.head())  #--> gives first 5 rows
# Out:
#        name  roll no  marks
# 0   dheeraj      101     10
# 1     kunal      102     20
# 2  abhishek      103     30
# 3   praveen      104     40
# 4    anjali      105     50

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.head(2)) #--> gives first 2 rows
# Out:
#       name  roll no  marks
# 0  dheeraj      101     10
# 1    kunal      102     20

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.head(-1))  #--> removes last 1 row
# Out:
#        name  roll no  marks
# 0   dheeraj      101     10
# 1     kunal      102     20
# 2  abhishek      103     30
# 3   praveen      104     40

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.head(-3))  #--> removes last 3 row
# Out:
#       name  roll no  marks
# 0  dheeraj      101     10
# 1    kunal      102     20

# %%
# df.tail()
# Shows the last 5 rows (or last n rows if specified).

import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.tail())
# Out:
#        name  roll no  marks
# 0   dheeraj      101     10
# 1     kunal      102     20
# 2  abhishek      103     30
# 3   praveen      104     40
# 4    anjali      105     50

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.tail(2))
# Out:
#       name  roll no  marks
# 3  praveen      104     40
# 4   anjali      105     50

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.tail(-2))
# Out:
#        name  roll no  marks
# 2  abhishek      103     30
# 3   praveen      104     40
# 4    anjali      105     50

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.tail(-5))

# output ---> means that your DataFrame has columns, but it contains no rows (no data).
# Out:
# Empty DataFrame
# Columns: [name, roll no, marks]
# Index: []

# %%
#df.shape --> Tells you the size of the DataFrame.
# output --> (rows,columns)
# df.shape[0]      # Number of rows
# df.shape[1]      # Number of columns

import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.shape)
# Out:
# (5, 3)

# %%
import pandas as pd
df = pd.DataFrame(data = [10,20,30,40,50],columns = ["age"])
print(df.shape)
print()
print(df)
# Out:
# (5, 1)
#
#    age
# 0   10
# 1   20
# 2   30
# 3   40
# 4   50

# %%
import pandas as pd
df = pd.Series(data = [10,20,30,40,50])
print(df.shape)
print()
print(df)
# Out:
# (5,)
#
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# df.info()  --> Gives detailed information about the DataFrame.
# output:-
# | Part           | Meaning                                        |
# | -------------- | ---------------------------------------------- |
# | RangeIndex     | Number of rows                                 |
# | Data columns   | Total columns                                  |
# | Column         | Column names                                   |
# | Non-Null Count | Number of non-empty values                     |
# | Dtype          | Data type (`int64`, `float64`, `object`, etc.) |
# | Memory usage   | RAM used by the DataFrame                      |
#
# Use: To check:
# Missing values,
# Data types,
# Number of rows,
# Number of columns

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.info()) #gives none due to this at end
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   roll no  5 non-null      int64
#  2   marks    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes
# None

# %% [markdown]
# df.info(verbose=True)
#
# verbose=True is a parameter used in many Python functions and libraries. It controls how much information the function prints while it is running.
#
# Think of it as a "talkative mode."
#
# verbose=True → Show detailed messages.
#
# verbose=False → Stay quiet and show little or no extra information.

# %%
import pandas as pd
import numpy as np
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
df["salary"] = [100,200,300,np.nan,500]
print(df)

# np.nan stands for NumPy Not a Number.
# It is a special value used to represent missing, unknown, or undefined data.
# Out:
#        name  roll no  marks  salary
# 0   dheeraj      101     10   100.0
# 1     kunal      102     20   200.0
# 2  abhishek      103     30   300.0
# 3   praveen      104     40     NaN
# 4    anjali      105     50   500.0

# %%
# rename()
# Purpose: Changes column names or row labels.

import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.rename(columns = {"name":"student_name"}))
print()
print(df)
# Out:
#   student_name  roll no  marks
# 0      dheeraj      101     10
# 1        kunal      102     20
# 2     abhishek      103     30
# 3      praveen      104     40
# 4       anjali      105     50
#
#        name  roll no  marks
# 0   dheeraj      101     10
# 1     kunal      102     20
# 2  abhishek      103     30
# 3   praveen      104     40
# 4    anjali      105     50

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df)
df.rename(columns = {"name":"student_name","marks":"salary"},inplace = True)
# print(df.rename(columns = {"name":"student_name"},inplace = True))  ---> gives error for print
print()
print(df)

# inplace=False (default) → Make a copy, leaving the original unchanged.
# inplace=True → Edit the original document.
# Out:
#        name  roll no  marks
# 0   dheeraj      101     10
# 1     kunal      102     20
# 2  abhishek      103     30
# 3   praveen      104     40
# 4    anjali      105     50
#
#   student_name  roll no  salary
# 0      dheeraj      101      10
# 1        kunal      102      20
# 2     abhishek      103      30
# 3      praveen      104      40
# 4       anjali      105      50

# %% [markdown]
# df.describe():-  Gives statistical summary of numeric columns.
#
# 1) count -->
# Number of non-missing values.
# 2) mean -->
# Average value.
# 3) std (Standard Deviation) --> Shows how much the values vary from the average.
#
# Small std → Values are close to the mean.
#
# Large std → Values are spread out.
#
# 4) min --> smallest value
# 5) 25% (First Quartile / Q1) --> 25% of the values are less than or equal to this value.
# 6) 50% (Median / Q2) -->
# The middle value when the data is sorted.
# 7) 75% (Third Quartile / Q3) -->
# 75% of the values are less than or equal to this value.
# 8) max --> largest value
#
# describe() for text columns
#
# Normally, describe() works only on numeric columns.
#
# If you want information about text (object) columns, use:
#
# df.describe(include="object")
#
# count → Number of non-empty values
#
# unique → Number of unique values
#
# top → Most frequent value
#
# freq → Frequency of the most frequent value

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df.describe())
# Out:
#           roll no      marks
# count    5.000000   5.000000
# mean   103.000000  30.000000
# std      1.581139  15.811388
# min    101.000000  10.000000
# 25%    102.000000  20.000000
# 50%    103.000000  30.000000
# 75%    104.000000  40.000000
# max    105.000000  50.000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
data = {
    "Emp_ID": [101,102,103,104,105,106],
    "Name": ["Amit","Riya","Raj","Sara","John","Neha"],
    "Department": ["IT","HR","Finance","IT","Sales","HR"],
    "Salary": [50000, 45000, 60000, 55000, 48000, 52000],
    "Experience": [2, 3, 5, 4, 1, 3]
}
df = pd.DataFrame(data)
print(df)
print("\n")

print(df.head(3))
print("\n")

print(df.tail(3))
print("\n")

print(df.shape)
print("\n")

df.info()
print("\n")

print(df.rename(columns = {"Name":"User_ID"}))
print("\n")

print(df.describe())
# Out:
#    Emp_ID  Name Department  Salary  Experience
# 0     101  Amit         IT   50000           2
# 1     102  Riya         HR   45000           3
# 2     103   Raj    Finance   60000           5
# 3     104  Sara         IT   55000           4
# 4     105  John      Sales   48000           1
# 5     106  Neha         HR   52000           3
#
#
#    Emp_ID  Name Department  Salary  Experience
# 0     101  Amit         IT   50000           2
# 1     102  Riya         HR   45000           3
# 2     103   Raj    Finance   60000           5
#
#
#    Emp_ID  Name Department  Salary  Experience
# 3     104  Sara         IT   55000           4
# 4     105  John      Sales   48000           1
# 5     106  Neha         HR   52000           3
#
#
# (6, 5)
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Emp_ID      6 non-null      int64
# ...

# %% [markdown]
# **Operation on Columns**
#
# 1) df["column name"] -> selecting column
# 2) df["column name"] = [values] -> add new column
# 3) df.drop("column name",axis=1) -> delete column
# 4) type(df[["column name", "column name"]])
# 5) df.drop(["col1", "col2"], axis=1)
# 6) df[["Name","Salary"]] -> Select Multiple Columns
# 7) df["Bonus"] = values -> Add New Column
# 8) df["Bonus"] = df["Salary"] + 5000 -> Add Calculated Column
# 9) df.drop("Experience", axis=1) -> Delete Single Column
# 10) df.drop(["Department","Experience"], axis=1) -> Delete Multiple Columns
# 11) df.drop("Department", axis=1, inplace=True) -> Permanent Delete
# 12) type(df["Name"]) -> Type of Single Column
# 13) type(df[["Name","Salary"]]) -> Type of Multiple Columns

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
print(df["name"]) #get single column data
print("\n")
df["salary"] = [100,200,300,400,500] #add single column
print(df)
# Out:
# 0     dheeraj
# 1       kunal
# 2    abhishek
# 3     praveen
# 4      anjali
# Name: name, dtype: object
#
#
#        name  roll no  marks  salary
# 0   dheeraj      101     10     100
# 1     kunal      102     20     200
# 2  abhishek      103     30     300
# 3   praveen      104     40     400
# 4    anjali      105     50     500

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/himani098/python-fundamentals/main/students_sample_02.json"
df = pd.read_json(url)
df["salary"] = df["marks"] + 100 #add single column
# print(df)
df
# Out:
#        name  roll no  marks  salary
# 0   dheeraj      101     10     110
# 1     kunal      102     20     120
# 2  abhishek      103     30     130
# 3   praveen      104     40     140
# 4    anjali      105     50     150

# %%
import pandas as pd
d = {
    "name":["vishal","virat","vineet"], # 3 rows
    "salary":[100,200,300] # 3 rows
}
df = pd.DataFrame(data=d)
# add column
# df["marks"] = [10,20,30]
df["marks"] = df["salary"] / 2
df["increment"] = df["salary"] + (df["salary"] / 10)
# column name change
df.rename(columns={"increment":"salary_increment"},inplace=True)
df
# Out:
#      name  salary  marks  salary_increment
# 0  vishal     100   50.0             110.0
# 1   virat     200  100.0             220.0
# 2  vineet     300  150.0             330.0
