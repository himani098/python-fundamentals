# %% [markdown]
# <a href="https://colab.research.google.com/github/himani098/python-fundamentals/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **module** - a .py file
#
# **package** - collection of modules, works like a folder
#
# **library** - collection of packages and modules
# ex - import math
#
# **framework** - already existing structure of an application
# ex - fast api, django , flask
#
# **full stack** = frontend + backend
#
# **frontend** - react
#
# **backend** - express , node , django, spring
#
# **python** - high level language(human understable)

# %%
a = 10
b = a
a = 30
print(a,b)
print(id(a),id(b))
#id() -> to access the memory address
# Out:
# 30 10
# 11646280 11645640

# %%
# integer
a = 10
print(a)
print(type(a))

#float
b = 10.10
print(b)
print(type(b))

# string
c = "hello"
print(c)
print(type(c))

# boolean
d = False
print(d)
print(type(d))
# Out:
# 10
# <class 'int'>
# 10.1
# <class 'float'>
# hello
# <class 'str'>
# False
# <class 'bool'>
