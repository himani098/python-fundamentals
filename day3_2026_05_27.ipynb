# %% [markdown]
# <a href="https://colab.research.google.com/github/himani098/python-fundamentals/blob/main/day3_2026_05_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Bitwise operator ->**
# # >> , << , & , | , ^

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# & -> ampersand  -> logical and
a = 5 # 101
b = 2 # 010
print(a & b)
# Out:
# 0

# %%
# | -> logical or
a = 5
b = 2
print(a | b)
# Out:
# 7

# %%
# ^ -> logical XOR
a = 5
b = 2
print(a ^ b)
# Out:
# 7

# %%
# >> -> right shift
a = 5
b = 2
print(a >> b) #101 --> 001
# Out:
# 1

# %%
# << -> left shift
a = 5
b = 2
print(a << b) #101 --> 10100
# Out:
# 20

# %% [markdown]
# **alternative for >> and <<**
#
# a >> n   --> a // (2^n)
#
# a << n   --> a * (2^n)

# %%
print(22 // 2)
print(22 >> 1)
print("\n")
print(22 // 4)
print(22 >> 2)
# Out:
# 11
# 11
#
#
# 5
# 5

# %%
print(22 * 2)
print(22 << 1)
print("\n")
print(22 * 4)
print(22 << 2)
# Out:
# 44
# 44
#
#
# 88
# 88

# %% [markdown]
# **identity operators ->**
# # is | is not

# %%
# example 1
num = 10
num1 = 10
print(num == num1 ) # value based
print(num is num1) # address based
print(id(num))
print(id(num1))
# Out:
# True
# True
# 11645640
# 11645640

# %%
# example 2
num = -5
num1 = -5
print(num == num1 )
print(num is not num1)
#is not gives the opposite output of is
print(id(num))
print(id(num1))
# Out:
# True
# False
# 11645160
# 11645160

# %%
# example 3
num = -7
num1 = -7
print(num == num1 )
print(num is num1)
print(id(num))
print(id(num1))
# Out:
# True
# False
# 137252185636400
# 137252185636816

# %%
# example 4
num = 256
num1 = 256
print(num == num1)
print(num is num1)
print(id(num))
print(id(num1))
# Out:
# True
# True
# 11653512
# 11653512

# %%
# example 4
num = 260
num1 = 260
print(num == num1 )
print(num is num1)
print(id(num))
print(id(num1))
# Out:
# True
# False
# 137252185636208
# 137252185635920

# %%
#(-5 to 256) -> both variable point on same address in this range

# example 5
num = 10
num1 = 10.0
print(num == num1 )
print(num is num1)
print(id(num))
print(id(num1))
# Out:
# True
# False
# 11645640
# 137252185635504

# %%
#example 6
#[] -> list -> two same list have different addresses
#but when assigned through two different varaibles assigning each other then it has same address
#() -> tuple
#{} -> dictionary

num1 = [1,2,3]
num2 = [1,2,3]
num3 = num1
print(num1 == num2)
print(num1 is num2)
print("\n")

print(num1 == num3)
print(num1 is num3)
print("\n")

print(num3 == num2)
print(num3 is num2)
print("\n")

print(id(num1))
print(id(num2))
print(id(num3))
# Out:
# True
# False
#
#
# True
# True
#
#
# True
# False
#
#
# 140105270877376
# 140105271097536
# 140105270877376

# %% [markdown]
# **Conditional Statements ->**
# # if
# # elif
# # else

# %%
# if
num1 = 10
num2 = 20
if num1 < num2 :
  print(num2)
# Out:
# 20

# %%
# if else
num1 = int(input("enter the number: "))
if num1 :
  print("number:-",num1)
else:
  print("zero",num1)
# Out:
# enter the number: 10
# number:- 10

# %%
# if elif else
age = int(input("Enter the number: "))
if age == 18:
  print("your age is: ",age)
elif age > 18 :
  print("you are above then 18 <",age)
else:
  print("you are less than 18 >",age)
# Out:
# Enter the number: 20
# you are above then 18 < 20

# %%
marks = int(input("Enter the marks:"))
if marks >= 90 and marks <= 100:
  print("A grade")
elif marks >= 75 and marks < 90:
  print("B grade")
elif marks >= 60 and marks < 75:
  print("C grade")
else :
  print("Fail")
# Out:
# Enter the marks:55
# Fail

# %%
marks = int(input("Enter the marks:"))
if marks >= 90 :
  print("A grade")
elif marks >= 75 :
  print("B grade")
elif marks >= 60 :
  print("C grade")
else :
  print("Fail")

#As soon as one if or elif condition becomes True,
#Python executes that block and skips all remaining elif and else blocks.

#one if and one else and any no of elif
# Out:
# Enter the marks:88
# B grade

# %% [markdown]
# **indentation** - space given in python to separate different code blocks

# %% [markdown]
# **loops ->**
# #for
# #while
# #break , continue, pass

# %%
#for
for i in range(5):
  #runs from 0 to 4
  # 0 is the by default starting value of it
  print("i = ",i)

#In a while loop, you manually increment i & also initiate i.
#In a for loop, Python automatically increment i and initiatialization done by range value.
# Out:
# i =  0
# i =  1
# i =  2
# i =  3
# i =  4

# %%
#for
for i in range(1,11):
  # runs from 1 to 10
  print("number = ",i)
# Out:
# number =  1
# number =  2
# number =  3
# number =  4
# number =  5
# number =  6
# number =  7
# number =  8
# number =  9
# number =  10

# %%
# list
# indexing starts from 0
# position and length starts from 1

l = [11,12,13,14]
print(len(l))
# len() -> used to find the length
print("\n")

for i in range(4):
  print(l[i])
print("\n")

# or
for i in range(len(l)):
  print(l[i])
print("\n")

# or
for i in l:
  print(i)
# Out:
# 4
#
#
# 11
# 12
# 13
# 14
#
#
# 11
# 12
# 13
# 14
#
#
# 11
# 12
# 13
# 14

# %%
#while
num1 = int(input("Enter the number: "))
i = 0
while i < num1 :
  print(i)
  i += 1
# Out:
# Enter the number: 4
# 0
# 1
# 2
# 3

# %%
# list
l = [10,11,12,13,14,15]
i = 0
while i < len(l):
  print(l[i])
  i += 1
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
# example for | while
d = {"name":"himani","age":20,"phone":"00000000"}
# phone no writen in string bcz no calculation done on it
l = d.keys()
print(l)
print("\n")

for i in range(len(d.keys())): #range(3)
  print(i)
print("\n")

for i in d: #keys
#Take each element(key) from the dictionary
    print(i)
print("\n")

for i in d.values(): #values of keys
    print(i)
print("\n")

for key, value in d.items(): #for both key and value
    print(key, value)
# Out:
# dict_keys(['name', 'age', 'phone'])
#
#
# 0
# 1
# 2
#
#
# name
# age
# phone
#
#
# himani
# 20
# 00000000
#
#
# name himani
# age 20
# phone 00000000

# %%
d = {"name":"himani","age":20,"phone":"00000000"}
for i in d.keys():
    print(i)
print("\n")

for i in d.items():
    print(i)
# Out:
# name
# age
# phone
#
#
# ('name', 'himani')
# ('age', 20)
# ('phone', '00000000')

# %%
# list example
l = [10,[11,12,13,14,15]]
print(l[1])
print("\n")

for i in l[1]:
  print(i)
print("\n")

print("second approch")

for i in range(2,len(l[1])):
   print(l[1][i])
# Out:
# [11, 12, 13, 14, 15]
#
#
# 11
# 12
# 13
# 14
# 15
#
#
# second approch
# 13
# 14
# 15

# %%
# break
for i in range(5):
  if i == 2:
    break
  print(i)
# Out:
# 0
# 1

# %%
# continue
i = 0
while True:
  print(i)
  if i == 5:
    break #stops the loop there and don't run further
  else:
    i += 1
    continue #skips the current iteration and moves to the next one.
    # also skips anything written after continue
    print("hello")
#if you don't have a specific condition for while loop apply it till true value
#and stop by using break, continue.
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# pass
#when no statement given in the if block then it gives error
#so when we don't want to write any statement in it
#and we don't want error also then we write pass in it to avoid any error
i = 0
while True:
  print(i)
  if i == 4:
    pass
  if i == 5:
    break
  else:
    i += 1
    continue
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#HW
# question 1

# ATM PIN Validation

correct_pin = 23456
attempts = 3
for i in range(attempts):
  pin = int(input("Enter the pin: "))
  if correct_pin == pin :
    print("Login Successful")
    break;
  else :
    attempts -= 1
    print("Incorrect Pin")
    print("Attempts left:", attempts)
    if attempts == 0:
      print("Account Blocked")
    else:
      print("Try again...")
# Out:
# Enter the pin: 343442
# Incorrect Pin
# Attempts left: 2
# Try again...
# Enter the pin: 5646
# Incorrect Pin
# Attempts left: 1
# Try again...
# Enter the pin: 65757
# Incorrect Pin
# Attempts left: 0
# Account Blocked

# %%
# question 2

# Passwod Strength Checker

password = input("Enter the password: ")
uppercase = False
lowercase = False
digit = False
special_character = False

for ch in password:
    if ch.isupper():
        uppercase = True
    elif ch.islower():
        lowercase = True
    elif ch.isdigit():
        digit = True
    else:
        special_character = True

if len(password) < 8:
    print("Weak Password")

elif uppercase and lowercase and digit and special_character:
    print("Strong Password")

else:
    print("Medium Password")

#These are built-in string methods in Python.
#They check the type of characters in a string and return True or False.

# .isupper()
#Checks if a character/string is uppercase

# .islower()
#Checks if a character/string is lowercase.

# .isdigit()
#Checks if a character/string is a digit.

#The dot (.) is used to access something that belongs to an object.
#name = "HELLO"
#print(name.lower())
#name      → Object
#lower()   → Method belonging to that object
# Out:
# Enter the password: Akjdiu78@k
# Strong Password

# %%
#question 3

# Multiplication Table of a Number

num = int(input("Enter a number: "))
if num > 0:
    print("Multiplication Table:")
    for i in range(1, 11):
        print(num, "x", i, "=", num * i)
else:
    print("Please enter a positive number")
# Out:
# Enter a number: 2
# Multiplication Table:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
#question 4

# Count Even and Odd Numbers from 1 to N

num = int(input("Enter the number:"))
even = 0
odd = 0
for i in range(1,num+1):
  if i % 2 == 0:
    even += 1
  else:
    odd += 1
print("Even Count =",even)
print("Odd Count =",odd)
# Out:
# Enter the number:10
# Even Count = 5
# Odd Count = 5

# %%
#question 5

#Number Guessing Game

secrete_number = 555
while True:
  guess = int(input("Enter the number:"))
  if guess == secrete_number:
    print("Correct Guess")
    print("You WIN !!")
    break
  elif guess < secrete_number:
    print("Guess Higher")
  else:
    print("Guess Lower")
# Out:
# Enter the number:345
# Guess Higher
# Enter the number:999
# Guess Lower
# Enter the number:556
# Guess Lower
# Enter the number:555
# Correct Guess
# You WIN !!
